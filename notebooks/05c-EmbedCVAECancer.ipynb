# %%
import torch
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report

from scarches.dataset.trvae.data_handling import remove_sparsity
from lataq.models import EMBEDCVAE
from lataq.exp_dict import EXPERIMENT_INFO

sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %load_ext autoreload
# %autoreload 2

# %%
PARAMS = {
    'EPOCHS': 50,                                      #TOTAL TRAINING EPOCHS
    'N_PRE_EPOCHS': 40,                                #EPOCHS OF PRETRAINING WITHOUT LANDMARK LOSS
    #'DATA_DIR': '../../lataq_reproduce/data',         #DIRECTORY WHERE THE DATA IS STORED
    #'DATA': '',                                       #DATA USED FOR THE EXPERIMENT
    'EARLY_STOPPING_KWARGS': {                         #KWARGS FOR EARLY STOPPING
        "early_stopping_metric": "val_landmark_loss",  ####value used for early stopping
        "mode": "min",                                 ####choose if look for min or max
        "threshold": 0,
        "patience": 20,
        "reduce_lr": True,
        "lr_patience": 13,
        "lr_factor": 0.1,
    },
    'LABELED_LOSS_METRIC': 'dist',           
    'UNLABELED_LOSS_METRIC': 'dist',
    'LATENT_DIM': 10,
    'ALPHA_EPOCH_ANNEAL': 1e3,
    'CLUSTERING_RES': 2,
    'HIDDEN_LAYERS': 3,
    'ETA': 10,
}

# %%
pd.crosstab(target_adata.obs['patient'], target_adata.obs['cell_type'])
# Out:
# cell_type  B cells  Cytotoxic CD8 T cells  Effector memory CD8 T cells  \
# patient
# BC_1           278                    177                           52
# BC_2            35                    852                           17
# BC_3            98                    100                           30
# BC_4           147                   1486                           41
# BC_5           434                    611                           44
# BC_6           111                    344                           18
# BC_7           138                    519                           15
# BC_8             6                    113                           13
#
# cell_type  M2 TAMs  Mast cells  Monocytes   NK  Naive T cells  \
# patient
# BC_1           112         244          9   49            162
# BC_2            58          49         15   83            408
# BC_3           114         137         90   51             42
# BC_4           181         425        148  721           1083
# BC_5           394         114        226  156            287
# BC_6           822         177         44   98            172
# BC_7           194         281        123  135            383
# BC_8            80          67         20   41             44
#
# cell_type  Naive-memory CD4 T cells  Plasma B cells  ...  \
# patient                                              ...
# BC_1                           1480              60  ...
# BC_2                            310              20  ...
# BC_3                            227              25  ...
# BC_4                            403              28  ...
# BC_5                             65              17  ...
# BC_6                             44              18  ...
# BC_7                             69              11  ...
# BC_8                             40              11  ...
#
# cell_type  Recently activated CD4 T cells  Regulatory T cells  SPP1 TAMs  \
# patient
# BC_1                                 1558                  18         42
# BC_2                                  656                 174         30
# BC_3                                  411                  79         95
# BC_4                                  498                  85         82
# BC_5                                  318                 505        239
# BC_6                                  403                  48       1696
# BC_7                                  304                  59        275
# BC_8                                  459                  24        168
#
# cell_type  T helper cells  Terminally exhausted CD8 T cells  Th17 cells  \
# patient
# BC_1                    6                                 2          20
# BC_2                   52                                50         113
# BC_3                   11                                22          58
# BC_4                   41                                30         173
# BC_5                   50                               109         289
# BC_6                   20                                65          39
# BC_7                   24                                29          53
# BC_8                    5                                 6          15
#
# cell_type  Transitional memory CD4 T cells  cDC  mDC  pDC
# patient
# BC_1                                    32    2   34    1
# BC_2                                   196    2   11    0
# BC_3                                    40   12  124    1
# BC_4                                   139   12   57    2
# BC_5                                    16   33  100   20
# BC_6                                    10   19   86    1
# BC_7                                    15   29  174    0
# BC_8                                     0    5   39    0
#
# [8 rows x 25 columns]

# %%
DATA_DIR = '../data'
adata = sc.read(f'{DATA_DIR}/cancer_atlas.h5ad')
remove_ct = ["B cells"]
query = adata.obs['patient'][adata.obs['patient'].str.contains('BC')]
adata.obs['query'] = adata.obs['patient'].isin(query)
adata.obs['query'] = adata.obs['query'].astype('category')
source_adata = adata[~adata.obs['patient'].isin(query)]
source_adata = adata[~adata.obs['cell_type'].isin(remove_ct)]
target_adata = adata[adata.obs['patient'].isin(query)]

# %%
adata_tmp = adata.copy()
sc.pp.normalize_total(adata_tmp)
sc.pp.log1p(adata_tmp)
sc.pp.highly_variable_genes(adata_tmp, n_top_genes=4000)
adata.var = adata_tmp.var
adata = adata[:, adata.var['highly_variable']]
source_adata = adata[adata.obs[condition_key].isin(reference)].copy()
target_adata = adata[adata.obs[condition_key].isin(query)].copy()

# %%
lataq_model = EMBEDCVAE(
    adata=source_adata,
    condition_key=condition_key,
    cell_type_keys=cell_type_key,
    hidden_layer_sizes=[128]*int(PARAMS['HIDDEN_LAYERS']),
    latent_dim=PARAMS['LATENT_DIM'],
)
# Out:
# Embedding dictionary:
#  	Num conditions: 80
#  	Embedding dim: 10
# Encoder Architecture:
# 	Input Layer in, out and cond: 4000 128 0
# 	Hidden Layer 1 in/out: 128 128
# 	Hidden Layer 2 in/out: 128 128
# 	Mean/Var Layer in/out: 128 10
# Decoder Architecture:
# 	First Layer in, out and cond:  10 128 10
# 	Hidden Layer 1 in/out: 128 128
# 	Hidden Layer 2 in/out: 128 128
# 	Output Layer in/out:  128 4000

# %%
lataq_model.train(
    n_epochs=PARAMS['EPOCHS'],
    pretraining_epochs=PARAMS['N_PRE_EPOCHS'],
    early_stopping_kwargs=PARAMS['EARLY_STOPPING_KWARGS'],
    alpha_epoch_anneal=PARAMS['ALPHA_EPOCH_ANNEAL'],
    eta=PARAMS['ETA'],
    clustering_res=PARAMS['CLUSTERING_RES'],
    labeled_loss_metric=PARAMS['LABELED_LOSS_METRIC'],
    unlabeled_loss_metric=PARAMS['UNLABELED_LOSS_METRIC'],
)
# Out:
#  |████████████████████| 100.0%  - val_loss: 525.1931906680 - val_trvae_loss: 516.6475039519 - val_landmark_loss: 8.5456859928 - val_labeled_loss: 0.8545685981
# Saving best state of network...
# Best State was in Epoch 48

# %%
lataq_model.save('tmp/', overwrite=True)

# %%
lataq_query = lataq_model.load_query_data(
    adata=target_adata,
    reference_model='tmp/',
    labeled_indices=[],
)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-14-fa71a123f6ce> in <module>
# ----> 1 lataq_query = lataq_model.load_query_data(
#       2     adata=target_adata,
#       3     reference_model='tmp/',
#       4     labeled_indices=[],
#       5 )
#
# /storage/groups/ml01/workspace/carlo.dedonno/LATAQ/lataq/models/embedcvae/embedcvae_model.py in load_query_data(cls, adata, reference_model, labeled_indices, unknown_ct_names, freeze, freeze_expression, remove_dropout)
#     148         """
#     149         if isinstance(reference_model, str):
# --> 150             attr_dict, model_state_dict, var_names = cls._load_params(reference_model)
#     151             _validate_var_names(adata, var_names)
#     152         else:
#
# /storage/groups/ml01/workspace/carlo.dedonno/scarches/scarches/models/base/_base.py in _load_params(cls, dir_path, map_location)
#     113
#     114         with open(setup_dict_path, "rb") as handle:
# --> 115             attr_dict = pickle.load(handle)
#     116
#     117         model_state_dict = torch.load(model_path, map_location=map_location)
#
# EOFError: Ran out of input

# %%
lataq_query.train(
    n_epochs=PARAMS['EPOCHS'],
    early_stopping_kwargs=PARAMS['EARLY_STOPPING_KWARGS'],
    alpha_epoch_anneal=PARAMS['ALPHA_EPOCH_ANNEAL'],
    pretraining_epochs=PARAMS['N_PRE_EPOCHS'],
    clustering_res=PARAMS['CLUSTERING_RES'],
    eta=PARAMS['ETA'],
    labeled_loss_metric=PARAMS['LABELED_LOSS_METRIC'],
    unlabeled_loss_metric=PARAMS['UNLABELED_LOSS_METRIC'],
)

# %%
results_dict = lataq_query.classify(
    adata.X, 
    adata.obs[condition_key], 
    metric=PARAMS['LABELED_LOSS_METRIC'],
)
for i in range(len(cell_type_key)):
    preds = results_dict[cell_type_key[i]]['preds']
    probs = results_dict[cell_type_key[i]]['probs']
    classification_df = pd.DataFrame(
        classification_report(
            y_true=adata.obs[cell_type_key[i]], 
            y_pred=preds,
            output_dict=True
        )
    ).transpose()
