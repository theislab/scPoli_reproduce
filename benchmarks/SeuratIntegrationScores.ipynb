# %%
import scanpy as sc
import pandas as pd
from lataq.metrics.metrics import metrics
from lataq_reproduce.exp_dict import EXPERIMENT_INFO

# %%
scores_list = []
for d in ['pancreas', 'pbmc', 'scvelo', 'lung', 'tumor', 'brain']:
    print(d)
    condition_key = EXPERIMENT_INFO[d]['condition_key']
    cell_type_key = EXPERIMENT_INFO[d]['cell_type_key'][0]
    adata = sc.read(f'../data/{d}.h5ad')
    adata_symphony = sc.AnnData(
        X=adata.obsm['X_symphony'],
        obs=adata.obs,
        #var=adata.var
    )
    scores = metrics(
        adata, 
        adata_symphony, 
        condition_key, 
        cell_type_key,
        nmi_=False,
        ari_=False,
        silhouette_=False,
        pcr_=True,
        graph_conn_=True,
        isolated_labels_=False,
        hvg_score_=False,
        ebm_=True,
        knn_=True,
    )
    scores = scores.assign(data=d)
    scores = scores.assign(method='symphony')
    scores_list.append(scores)
    scores_df = pd.concat(scores_list)
    scores_df.to_pickle('scores.pickle')
    if adata.obsm['X_seurat'] is not None:
        adata_seurat = sc.AnnData(
            X=adata.obsm['X_seurat'],
            obs=adata.obs,
            #var=adata.var
        )
        scores = metrics(
            adata, 
            adata_seurat, 
            condition_key, 
            cell_type_key,
            nmi_=False,
            ari_=False,
            silhouette_=True,
            pcr_=True,
            graph_conn_=True,
            isolated_labels_=False,
            hvg_score_=False,
            ebm_=True,
            knn_=True,
        )
        scores = scores.assign(data=d)
        scores = scores.assign(method='seurat')
        scores_list.append(scores)
        scores_df = pd.concat(scores_list)
        scores_df.to_pickle('scores.pickle')
# Out:
# pancreas
# PC regression...
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 9
# EBM: 0.6201118230770546
# KNN purity
# KNN-P: 0.8311141845644131
# silhouette score...
# PC regression...
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 9
# EBM: 0.5246511600595956
# KNN purity
# KNN-P: 0.8663417231041118
# pbmc
# PC regression...
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 9
# EBM: 0.5995954301299354
# KNN purity
# KNN-P: 0.8059959030365703
# silhouette score...
# PC regression...
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 9
# EBM: 0.5761802350319298
# KNN purity
# KNN-P: 0.7765404546968161
# scvelo
# PC regression...
# Variance contribution increased after integration!
# Setting PCR comparison score to 0.
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 4
# EBM: 0.5852027707719809
# KNN purity
# KNN-P: 0.713175807226616
# silhouette score...
# PC regression...
# Variance contribution increased after integration!
# Setting PCR comparison score to 0.
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 4
# EBM: 0.5839689031467298
# KNN purity
# KNN-P: 0.7038599222513757
# lung
# PC regression...
# Variance contribution increased after integration!
# Setting PCR comparison score to 0.
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 3
# EBM: 0.22408688054909848
# KNN purity
# KNN-P: 0.8341258079645855
# silhouette score...
# PC regression...
# Variance contribution increased after integration!
# Setting PCR comparison score to 0.
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 3
# EBM: 0.14396603174961844
# KNN purity
# KNN-P: 0.8179323121855794
# tumor
# PC regression...
# Variance contribution increased after integration!
# Setting PCR comparison score to 0.
# Graph connectivity...
# Entropy batch mixing...
# Calculating EBM with n_cat = 13
# EBM: 0.36536556371401635
# KNN purity
# KNN-P: 0.587462986302041
# silhouette score...
